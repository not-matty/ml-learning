# %%
import gym
import numpy as np
import random
from collections import deque
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

from IPython.display import HTML
import base64
import os
import glob

print(gym.__version__)
# Out:
# 0.26.2

# %%
# from gym import Wrapper

# class TimeDependentPenaltyWrapper(Wrapper):
#     def __init__(self, env):
#         super(TimeDependentPenaltyWrapper, self).__init__(env)
#         self.theta_threshold = 0.003  # radians (~2.86 degrees)
#         self.x_dot_threshold = 0.003  # cart velocity
#         self.current_step = 0

#     def reset(self, **kwargs):
#         # Reset the environment and step counter
#         self.current_step = 0
#         return self.env.reset(**kwargs)

#     def step(self, action):
#         # Step through the environment and increase the step count
#         self.current_step += 1
#         observation, reward, done, truncated, info = self.env.step(action)
        
#         x, x_dot, theta, theta_dot = observation

#         # Condition for being upright and still
#         is_upright = abs(theta) < self.theta_threshold
#         is_still = abs(x_dot) < self.x_dot_threshold

#         if is_upright and is_still:
#             reward = 100.0  # Large reward for upright and still
#         else:
#             # Time-dependent penalty for high velocity
#             velocity_penalty = self.current_step * abs(x_dot) * .001
#             reward = -velocity_penalty

#         return observation, reward, done, truncated, info

# %%
# Define the Q-Network
class DQN(nn.Module):
    def __init__(self, state_dim, action_dim, hidden1, hidden2):
        super(DQN, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(state_dim, hidden1),
            nn.ReLU(),
            nn.Linear(hidden1, hidden2),
            nn.ReLU(),
            nn.Linear(hidden2, action_dim)
        )
    
    def forward(self, x):
        return self.model(x)

# Define the Replay Buffer
class ReplayBuffer:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)

    def push(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))

    def sample(self, batch_size):
        return random.sample(self.buffer, batch_size)

    def __len__(self):
        return len(self.buffer)

# Define the Epsilon-Greedy Policy
def epsilon_greedy_policy(state, q_network, epsilon, action_dim):
    if random.random() < epsilon:
        return random.randint(0, action_dim - 1)
    else:
        state_tensor = torch.FloatTensor(state).unsqueeze(0)  # Corrected 'unsqueee' to 'unsqueeze'
        with torch.no_grad():
            q_values = q_network(state_tensor)
        return torch.argmax(q_values, dim=1).item()

# Define the DQN Agent
class DQNAgent:
    def __init__(self, state_dim, action_dim, hidden1=128, hidden2=128, 
                 learning_rate=0.001, gamma=0.99, buffer_capacity=10000, batch_size=64, tau=0.001):
        """
        Initialize the DQN Agent.

        Args:
            state_dim (int): Dimension of the state space.
            action_dim (int): Number of possible actions.
            hidden1 (int, optional): Number of neurons in the first hidden layer. Defaults to 128.
            hidden2 (int, optional): Number of neurons in the second hidden layer. Defaults to 128.
            learning_rate (float, optional): Learning rate for the optimizer. Defaults to 0.001.
            gamma (float, optional): Discount factor for future rewards. Defaults to 0.99.
            buffer_capacity (int, optional): Capacity of the replay buffer. Defaults to 10000.
            batch_size (int, optional): Number of samples per training batch. Defaults to 64.
            tau (float, optional): Soft update parameter. Defaults to 0.001.
        """
        # Initialize Q-Network
        self.q_network = DQN(state_dim, action_dim, hidden1, hidden2)
        self.target_network = DQN(state_dim, action_dim, hidden1, hidden2)
        self.target_network.load_state_dict(self.q_network.state_dict())
        self.target_network.eval()  # Set target network to evaluation mode

        # Optimizer and Loss Function
        self.optimizer = optim.Adam(self.q_network.parameters(), lr=learning_rate)
        self.loss_fn = nn.MSELoss()

        # Replay Buffer
        self.replay_buffer = ReplayBuffer(capacity=buffer_capacity)
        self.batch_size = batch_size

        # Discount Factor
        self.gamma = gamma

        # Soft Update Parameter
        self.tau = tau

    def select_action(self, state, epsilon, action_dim):
        """
        Select an action using the epsilon-greedy policy.

        Args:
            state (np.array): Current state.
            epsilon (float): Current epsilon value for exploration.
            action_dim (int): Number of possible actions.

        Returns:
            int: Selected action.
        """
        return epsilon_greedy_policy(state, self.q_network, epsilon, action_dim)

    def store_experience(self, state, action, reward, next_state, done):
        """
        Store an experience tuple in the replay buffer.

        Args:
            state (np.array): Current state.
            action (int): Action taken.
            reward (float): Reward received.
            next_state (np.array): Next state.
            done (bool): Whether the episode has ended.
        """
        self.replay_buffer.push(state, action, reward, next_state, done)

    def sample_experiences(self):
        """
        Sample a batch of experiences from the replay buffer.

        Returns:
            tuple: Tuple containing batches of states, actions, rewards, next_states, and dones.
        """
        batch = self.replay_buffer.sample(self.batch_size)
        states, actions, rewards, next_states, dones = zip(*batch)
        return states, actions, rewards, next_states, dones

    def update_q_network(self, states, actions, rewards, next_states, dones):
        """
        Update the Q-Network using a batch of experiences.

        Args:
            states (torch.Tensor): Batch of current states.
            actions (torch.Tensor): Batch of actions taken.
            rewards (torch.Tensor): Batch of rewards received.
            next_states (torch.Tensor): Batch of next states.
            dones (torch.Tensor): Batch of done flags.
        """
        # Compute Current Q-Values: Q(s, a)
        current_q = self.q_network(states).gather(1, actions)

        # Compute Next Q-Values: max_a Q(s', a') using Target Network
        with torch.no_grad():
            next_q = self.target_network(next_states).max(1)[0].unsqueeze(1)

        # Compute Target Q-Values: r + gamma * max_a Q(s', a') * (1 - done)
        target_q = rewards + self.gamma * next_q * (1 - dones)

        # Compute the Loss between Current Q and Target Q
        loss = self.loss_fn(current_q, target_q)

        # Perform Backpropagation and Optimization Step
        self.optimizer.zero_grad()  # Corrected 'zero' to 'zero_grad'
        loss.backward()
        self.optimizer.step()

        # Perform Soft Update of the Target Network
        self.soft_update_target_network()

    def soft_update_target_network(self):
        """
        Perform a soft update of the target network's weights.
        """
        for target_param, param in zip(self.target_network.parameters(), self.q_network.parameters()):
            target_param.data.copy_(self.tau * param.data + (1.0 - self.tau) * target_param.data)

    def train_step(self):
        """
        Perform a single training step by sampling experiences and updating the Q-Network.
        """
        # Check if Replay Buffer has Enough Samples
        if len(self.replay_buffer) < self.batch_size:
            return  # Not enough experiences to train

        # Sample a Batch of Experiences
        states, actions, rewards, next_states, dones = self.sample_experiences()

        # Convert Batches to Tensors
        states = torch.FloatTensor(states)          # Shape: [batch_size, state_dim]
        actions = torch.LongTensor(actions).unsqueeze(1)  # Shape: [batch_size, 1]
        rewards = torch.FloatTensor(rewards).unsqueeze(1)  # Shape: [batch_size, 1]
        next_states = torch.FloatTensor(next_states)      # Shape: [batch_size, state_dim]
        dones = torch.FloatTensor(dones).unsqueeze(1)      # Shape: [batch_size, 1]

        # Update the Q-Network
        self.update_q_network(states, actions, rewards, next_states, dones)

# %%
# Define the Training Function
def train_dqn_agent():
    env = gym.make("CartPole-v1")
    state_dim = env.observation_space.shape[0]
    action_dim = env.action_space.n

    hidden1 = 128
    hidden2 = 128
    learning_rate = 0.001
    gamma = 0.99
    buffer_capacity = 10000
    batch_size = 64
    num_episodes = 500
    tau = 0.001

    epsilon_start = 1.0
    epsilon_min = 0.01
    epsilon_decay = 0.995

    agent = DQNAgent(state_dim, action_dim, hidden1, hidden2, learning_rate, gamma, buffer_capacity, batch_size, tau)

    epsilon = epsilon_start

    rewards_history = []
    avg_rewards_history = []

    for episode in range(1, num_episodes + 1):
        state, _ = env.reset()
        done = False
        total_reward = 0

        while not done:
            action = agent.select_action(state, epsilon, action_dim)
            next_state, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated
            agent.store_experience(state, action, reward, next_state, done)
            state = next_state
            total_reward += reward

            # Update Q Network
            agent.train_step()

        # Decay Epsilon after Each Episode
        epsilon = max(epsilon_min, epsilon * epsilon_decay)

        rewards_history.append(total_reward)

        if episode >= 100:
            avg_reward = np.mean(rewards_history[-100:])
            avg_rewards_history.append(avg_reward)
            print(f"Episode {episode}/{num_episodes} - Total Reward: {total_reward} - Average Reward: {avg_reward:.2f} - Epsilon: {epsilon:.4f}")

            if avg_reward >= 195.0:
                print(f"Environment solved in {episode} episodes!")
                break

        else:
            print(f"Episode {episode}/{num_episodes} - Total Reward: {total_reward} - Epsilon: {epsilon:.4f}")

    env.close()     

    # Plotting the Rewards
    plt.figure(figsize=(12, 6))
    plt.plot(rewards_history, label='Total Reward')
    plt.plot(avg_rewards_history, label='Average Reward (100 episodes)')
    plt.xlabel('Episode')
    plt.ylabel('Reward')
    plt.title('DQN Training Progress on CartPole-v1')
    plt.legend()
    plt.show()   
    return agent

#video recording
import gym

def record_cartpole_video(agent, env_name="CartPole-v1", video_folder="/Users/matthew/Documents/ml_projects/videos/"):
    import os
    import glob
    from IPython.display import HTML, display
    import base64

    def display_video_inline(video_path, width=600):
        if not os.path.exists(video_path):
            print(f"Video file not found at: {video_path}")
            return
        mp4 = open(video_path, 'rb').read()
        data_url = "data:video/mp4;base64," + base64.b64encode(mp4).decode()
        return display(HTML(f"""<video width="{width}" controls>
                        <source src="{data_url}" type="video/mp4" />
                        Your browser does not support the video tag.
                       </video>"""))

    # Ensure the video directory exists
    os.makedirs(video_folder, exist_ok=True)
    print(f"Video will be saved to: {video_folder}")
    
    # Initialize environment with render_mode
    env = gym.make(env_name, render_mode="rgb_array")
    env = gym.wrappers.RecordVideo(env, video_folder=video_folder, episode_trigger=lambda x: True)
    
    state, _ = env.reset()
    done = False
    total_reward = 0
    
    while not done:
        action = agent.select_action(state, epsilon=0.0, action_dim=env.action_space.n)
        next_state, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated
        state = next_state
        total_reward += reward
    
    env.close()
    print(f"Episode finished with total reward: {total_reward}")
    
    # Retrieve the latest video
    video_files = glob.glob(os.path.join(video_folder, "*.mp4"))
    if not video_files:
        print("No video recorded.")
        return
    
    latest_video = max(video_files, key=os.path.getctime)
    print(f"Latest video file: {latest_video}")
    
    # Display the video inline
    display_video_inline(latest_video)


if __name__ == "__main__":
    trained_agent = train_dqn_agent()

    record_cartpole_video(trained_agent)
# Out:
# Episode 1/500 - Total Reward: 17.0 - Epsilon: 0.9950
# Episode 2/500 - Total Reward: 16.0 - Epsilon: 0.9900
# Episode 3/500 - Total Reward: 17.0 - Epsilon: 0.9851
# Episode 4/500 - Total Reward: 46.0 - Epsilon: 0.9801
# Episode 5/500 - Total Reward: 26.0 - Epsilon: 0.9752
# Episode 6/500 - Total Reward: 26.0 - Epsilon: 0.9704
# Episode 7/500 - Total Reward: 9.0 - Epsilon: 0.9655
# Episode 8/500 - Total Reward: 56.0 - Epsilon: 0.9607
# Episode 9/500 - Total Reward: 32.0 - Epsilon: 0.9559
# Episode 10/500 - Total Reward: 21.0 - Epsilon: 0.9511
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/gym/utils/passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# Episode 11/500 - Total Reward: 15.0 - Epsilon: 0.9464
# Episode 12/500 - Total Reward: 21.0 - Epsilon: 0.9416
# Episode 13/500 - Total Reward: 22.0 - Epsilon: 0.9369
# Episode 14/500 - Total Reward: 24.0 - Epsilon: 0.9322
# Episode 15/500 - Total Reward: 14.0 - Epsilon: 0.9276
# Episode 16/500 - Total Reward: 17.0 - Epsilon: 0.9229
# Episode 17/500 - Total Reward: 21.0 - Epsilon: 0.9183
# Episode 18/500 - Total Reward: 20.0 - Epsilon: 0.9137
# Episode 19/500 - Total Reward: 28.0 - Epsilon: 0.9092
# Episode 20/500 - Total Reward: 14.0 - Epsilon: 0.9046
# Episode 21/500 - Total Reward: 14.0 - Epsilon: 0.9001
# Episode 22/500 - Total Reward: 12.0 - Epsilon: 0.8956
# Episode 23/500 - Total Reward: 17.0 - Epsilon: 0.8911
# Episode 24/500 - Total Reward: 19.0 - Epsilon: 0.8867
# Episode 25/500 - Total Reward: 13.0 - Epsilon: 0.8822
# Episode 26/500 - Total Reward: 13.0 - Epsilon: 0.8778
# Episode 27/500 - Total Reward: 35.0 - Epsilon: 0.8734
# Episode 28/500 - Total Reward: 15.0 - Epsilon: 0.8691
# Episode 29/500 - Total Reward: 12.0 - Epsilon: 0.8647
# Episode 30/500 - Total Reward: 12.0 - Epsilon: 0.8604
# Episode 31/500 - Total Reward: 23.0 - Epsilon: 0.8561
# Episode 32/500 - Total Reward: 19.0 - Epsilon: 0.8518
# Episode 33/500 - Total Reward: 12.0 - Epsilon: 0.8475
# Episode 34/500 - Total Reward: 16.0 - Epsilon: 0.8433
# Episode 35/500 - Total Reward: 16.0 - Epsilon: 0.8391
# Episode 36/500 - Total Reward: 11.0 - Epsilon: 0.8349
# Episode 37/500 - Total Reward: 19.0 - Epsilon: 0.8307
# Episode 38/500 - Total Reward: 30.0 - Epsilon: 0.8266
# Episode 39/500 - Total Reward: 15.0 - Epsilon: 0.8224
# Episode 40/500 - Total Reward: 24.0 - Epsilon: 0.8183
# Episode 41/500 - Total Reward: 18.0 - Epsilon: 0.8142
# Episode 42/500 - Total Reward: 14.0 - Epsilon: 0.8102
# Episode 43/500 - Total Reward: 10.0 - Epsilon: 0.8061
# Episode 44/500 - Total Reward: 14.0 - Epsilon: 0.8021
# Episode 45/500 - Total Reward: 19.0 - Epsilon: 0.7981
# Episode 46/500 - Total Reward: 13.0 - Epsilon: 0.7941
# Episode 47/500 - Total Reward: 19.0 - Epsilon: 0.7901
# Episode 48/500 - Total Reward: 26.0 - Epsilon: 0.7862
# Episode 49/500 - Total Reward: 12.0 - Epsilon: 0.7822
# Episode 50/500 - Total Reward: 11.0 - Epsilon: 0.7783
# Episode 51/500 - Total Reward: 21.0 - Epsilon: 0.7744
# Episode 52/500 - Total Reward: 11.0 - Epsilon: 0.7705
# Episode 53/500 - Total Reward: 12.0 - Epsilon: 0.7667
# Episode 54/500 - Total Reward: 16.0 - Epsilon: 0.7629
# Episode 55/500 - Total Reward: 13.0 - Epsilon: 0.7590
# Episode 56/500 - Total Reward: 12.0 - Epsilon: 0.7553
# Episode 57/500 - Total Reward: 20.0 - Epsilon: 0.7515
# Episode 58/500 - Total Reward: 12.0 - Epsilon: 0.7477
# Episode 59/500 - Total Reward: 31.0 - Epsilon: 0.7440
# Episode 60/500 - Total Reward: 9.0 - Epsilon: 0.7403
# Episode 61/500 - Total Reward: 12.0 - Epsilon: 0.7366
# Episode 62/500 - Total Reward: 12.0 - Epsilon: 0.7329
# Episode 63/500 - Total Reward: 17.0 - Epsilon: 0.7292
# Episode 64/500 - Total Reward: 29.0 - Epsilon: 0.7256
# Episode 65/500 - Total Reward: 46.0 - Epsilon: 0.7219
# Episode 66/500 - Total Reward: 11.0 - Epsilon: 0.7183
# Episode 67/500 - Total Reward: 14.0 - Epsilon: 0.7147
# Episode 68/500 - Total Reward: 13.0 - Epsilon: 0.7112
# Episode 69/500 - Total Reward: 12.0 - Epsilon: 0.7076
# Episode 70/500 - Total Reward: 14.0 - Epsilon: 0.7041
# Episode 71/500 - Total Reward: 17.0 - Epsilon: 0.7005
# Episode 72/500 - Total Reward: 15.0 - Epsilon: 0.6970
# Episode 73/500 - Total Reward: 39.0 - Epsilon: 0.6936
# Episode 74/500 - Total Reward: 51.0 - Epsilon: 0.6901
# Episode 75/500 - Total Reward: 13.0 - Epsilon: 0.6866
# Episode 76/500 - Total Reward: 14.0 - Epsilon: 0.6832
# Episode 77/500 - Total Reward: 12.0 - Epsilon: 0.6798
# Episode 78/500 - Total Reward: 43.0 - Epsilon: 0.6764
# Episode 79/500 - Total Reward: 105.0 - Epsilon: 0.6730
# Episode 80/500 - Total Reward: 37.0 - Epsilon: 0.6696
# Episode 81/500 - Total Reward: 17.0 - Epsilon: 0.6663
# Episode 82/500 - Total Reward: 23.0 - Epsilon: 0.6630
# Episode 83/500 - Total Reward: 28.0 - Epsilon: 0.6597
# Episode 84/500 - Total Reward: 86.0 - Epsilon: 0.6564
# Episode 85/500 - Total Reward: 12.0 - Epsilon: 0.6531
# Episode 86/500 - Total Reward: 14.0 - Epsilon: 0.6498
# Episode 87/500 - Total Reward: 40.0 - Epsilon: 0.6466
# Episode 88/500 - Total Reward: 33.0 - Epsilon: 0.6433
# Episode 89/500 - Total Reward: 49.0 - Epsilon: 0.6401
# Episode 90/500 - Total Reward: 13.0 - Epsilon: 0.6369
# Episode 91/500 - Total Reward: 23.0 - Epsilon: 0.6337
# Episode 92/500 - Total Reward: 25.0 - Epsilon: 0.6306
# Episode 93/500 - Total Reward: 44.0 - Epsilon: 0.6274
# Episode 94/500 - Total Reward: 20.0 - Epsilon: 0.6243
# Episode 95/500 - Total Reward: 13.0 - Epsilon: 0.6211
# Episode 96/500 - Total Reward: 18.0 - Epsilon: 0.6180
# Episode 97/500 - Total Reward: 35.0 - Epsilon: 0.6149
# Episode 98/500 - Total Reward: 13.0 - Epsilon: 0.6119
# Episode 99/500 - Total Reward: 15.0 - Epsilon: 0.6088
# Episode 100/500 - Total Reward: 17.0 - Average Reward: 21.86 - Epsilon: 0.6058
# Episode 101/500 - Total Reward: 49.0 - Average Reward: 22.18 - Epsilon: 0.6027
# Episode 102/500 - Total Reward: 28.0 - Average Reward: 22.30 - Epsilon: 0.5997
# Episode 103/500 - Total Reward: 63.0 - Average Reward: 22.76 - Epsilon: 0.5967
# Episode 104/500 - Total Reward: 33.0 - Average Reward: 22.63 - Epsilon: 0.5937
# Episode 105/500 - Total Reward: 43.0 - Average Reward: 22.80 - Epsilon: 0.5908
# Episode 106/500 - Total Reward: 39.0 - Average Reward: 22.93 - Epsilon: 0.5878
# Episode 107/500 - Total Reward: 50.0 - Average Reward: 23.34 - Epsilon: 0.5849
# Episode 108/500 - Total Reward: 12.0 - Average Reward: 22.90 - Epsilon: 0.5820
# Episode 109/500 - Total Reward: 14.0 - Average Reward: 22.72 - Epsilon: 0.5790
# Episode 110/500 - Total Reward: 23.0 - Average Reward: 22.74 - Epsilon: 0.5762
# Episode 111/500 - Total Reward: 19.0 - Average Reward: 22.78 - Epsilon: 0.5733
# Episode 112/500 - Total Reward: 30.0 - Average Reward: 22.87 - Epsilon: 0.5704
# Episode 113/500 - Total Reward: 27.0 - Average Reward: 22.92 - Epsilon: 0.5676
# Episode 114/500 - Total Reward: 50.0 - Average Reward: 23.18 - Epsilon: 0.5647
# Episode 115/500 - Total Reward: 70.0 - Average Reward: 23.74 - Epsilon: 0.5619
# Episode 116/500 - Total Reward: 11.0 - Average Reward: 23.68 - Epsilon: 0.5591
# Episode 117/500 - Total Reward: 70.0 - Average Reward: 24.17 - Epsilon: 0.5563
# Episode 118/500 - Total Reward: 34.0 - Average Reward: 24.31 - Epsilon: 0.5535
# Episode 119/500 - Total Reward: 44.0 - Average Reward: 24.47 - Epsilon: 0.5507
# Episode 120/500 - Total Reward: 12.0 - Average Reward: 24.45 - Epsilon: 0.5480
# Episode 121/500 - Total Reward: 30.0 - Average Reward: 24.61 - Epsilon: 0.5452
# Episode 122/500 - Total Reward: 42.0 - Average Reward: 24.91 - Epsilon: 0.5425
# Episode 123/500 - Total Reward: 20.0 - Average Reward: 24.94 - Epsilon: 0.5398
# Episode 124/500 - Total Reward: 11.0 - Average Reward: 24.86 - Epsilon: 0.5371
# Episode 125/500 - Total Reward: 97.0 - Average Reward: 25.70 - Epsilon: 0.5344
# Episode 126/500 - Total Reward: 14.0 - Average Reward: 25.71 - Epsilon: 0.5318
# Episode 127/500 - Total Reward: 49.0 - Average Reward: 25.85 - Epsilon: 0.5291
# Episode 128/500 - Total Reward: 14.0 - Average Reward: 25.84 - Epsilon: 0.5264
# Episode 129/500 - Total Reward: 42.0 - Average Reward: 26.14 - Epsilon: 0.5238
# Episode 130/500 - Total Reward: 13.0 - Average Reward: 26.15 - Epsilon: 0.5212
# Episode 131/500 - Total Reward: 18.0 - Average Reward: 26.10 - Epsilon: 0.5186
# Episode 132/500 - Total Reward: 21.0 - Average Reward: 26.12 - Epsilon: 0.5160
# Episode 133/500 - Total Reward: 17.0 - Average Reward: 26.17 - Epsilon: 0.5134
# Episode 134/500 - Total Reward: 58.0 - Average Reward: 26.59 - Epsilon: 0.5108
# Episode 135/500 - Total Reward: 47.0 - Average Reward: 26.90 - Epsilon: 0.5083
# Episode 136/500 - Total Reward: 21.0 - Average Reward: 27.00 - Epsilon: 0.5058
# Episode 137/500 - Total Reward: 11.0 - Average Reward: 26.92 - Epsilon: 0.5032
# Episode 138/500 - Total Reward: 51.0 - Average Reward: 27.13 - Epsilon: 0.5007
# Episode 139/500 - Total Reward: 11.0 - Average Reward: 27.09 - Epsilon: 0.4982
# Episode 140/500 - Total Reward: 23.0 - Average Reward: 27.08 - Epsilon: 0.4957
# Episode 141/500 - Total Reward: 12.0 - Average Reward: 27.02 - Epsilon: 0.4932
# Episode 142/500 - Total Reward: 70.0 - Average Reward: 27.58 - Epsilon: 0.4908
# Episode 143/500 - Total Reward: 16.0 - Average Reward: 27.64 - Epsilon: 0.4883
# Episode 144/500 - Total Reward: 26.0 - Average Reward: 27.76 - Epsilon: 0.4859
# Episode 145/500 - Total Reward: 48.0 - Average Reward: 28.05 - Epsilon: 0.4834
# Episode 146/500 - Total Reward: 17.0 - Average Reward: 28.09 - Epsilon: 0.4810
# Episode 147/500 - Total Reward: 41.0 - Average Reward: 28.31 - Epsilon: 0.4786
# Episode 148/500 - Total Reward: 52.0 - Average Reward: 28.57 - Epsilon: 0.4762
# Episode 149/500 - Total Reward: 46.0 - Average Reward: 28.91 - Epsilon: 0.4738
# Episode 150/500 - Total Reward: 30.0 - Average Reward: 29.10 - Epsilon: 0.4715
# Episode 151/500 - Total Reward: 50.0 - Average Reward: 29.39 - Epsilon: 0.4691
# Episode 152/500 - Total Reward: 21.0 - Average Reward: 29.49 - Epsilon: 0.4668
# Episode 153/500 - Total Reward: 46.0 - Average Reward: 29.83 - Epsilon: 0.4644
# Episode 154/500 - Total Reward: 43.0 - Average Reward: 30.10 - Epsilon: 0.4621
# Episode 155/500 - Total Reward: 36.0 - Average Reward: 30.33 - Epsilon: 0.4598
# Episode 156/500 - Total Reward: 32.0 - Average Reward: 30.53 - Epsilon: 0.4575
# Episode 157/500 - Total Reward: 70.0 - Average Reward: 31.03 - Epsilon: 0.4552
# Episode 158/500 - Total Reward: 13.0 - Average Reward: 31.04 - Epsilon: 0.4529
# Episode 159/500 - Total Reward: 13.0 - Average Reward: 30.86 - Epsilon: 0.4507
# Episode 160/500 - Total Reward: 107.0 - Average Reward: 31.84 - Epsilon: 0.4484
# Episode 161/500 - Total Reward: 84.0 - Average Reward: 32.56 - Epsilon: 0.4462
# Episode 162/500 - Total Reward: 160.0 - Average Reward: 34.04 - Epsilon: 0.4440
# Episode 163/500 - Total Reward: 126.0 - Average Reward: 35.13 - Epsilon: 0.4417
# Episode 164/500 - Total Reward: 43.0 - Average Reward: 35.27 - Epsilon: 0.4395
# Episode 165/500 - Total Reward: 16.0 - Average Reward: 34.97 - Epsilon: 0.4373
# Episode 166/500 - Total Reward: 50.0 - Average Reward: 35.36 - Epsilon: 0.4351
# Episode 167/500 - Total Reward: 51.0 - Average Reward: 35.73 - Epsilon: 0.4330
# Episode 168/500 - Total Reward: 51.0 - Average Reward: 36.11 - Epsilon: 0.4308
# Episode 169/500 - Total Reward: 14.0 - Average Reward: 36.13 - Epsilon: 0.4286
# Episode 170/500 - Total Reward: 108.0 - Average Reward: 37.07 - Epsilon: 0.4265
# Episode 171/500 - Total Reward: 37.0 - Average Reward: 37.27 - Epsilon: 0.4244
# Episode 172/500 - Total Reward: 117.0 - Average Reward: 38.29 - Epsilon: 0.4223
# Episode 173/500 - Total Reward: 52.0 - Average Reward: 38.42 - Epsilon: 0.4201
# Episode 174/500 - Total Reward: 55.0 - Average Reward: 38.46 - Epsilon: 0.4180
# Episode 175/500 - Total Reward: 31.0 - Average Reward: 38.64 - Epsilon: 0.4159
# Episode 176/500 - Total Reward: 70.0 - Average Reward: 39.20 - Epsilon: 0.4139
# Episode 177/500 - Total Reward: 31.0 - Average Reward: 39.39 - Epsilon: 0.4118
# Episode 178/500 - Total Reward: 51.0 - Average Reward: 39.47 - Epsilon: 0.4097
# Episode 179/500 - Total Reward: 111.0 - Average Reward: 39.53 - Epsilon: 0.4077
# Episode 180/500 - Total Reward: 36.0 - Average Reward: 39.52 - Epsilon: 0.4057
# Episode 181/500 - Total Reward: 60.0 - Average Reward: 39.95 - Epsilon: 0.4036
# Episode 182/500 - Total Reward: 41.0 - Average Reward: 40.13 - Epsilon: 0.4016
# Episode 183/500 - Total Reward: 41.0 - Average Reward: 40.26 - Epsilon: 0.3996
# Episode 184/500 - Total Reward: 72.0 - Average Reward: 40.12 - Epsilon: 0.3976
# Episode 185/500 - Total Reward: 35.0 - Average Reward: 40.35 - Epsilon: 0.3956
# Episode 186/500 - Total Reward: 123.0 - Average Reward: 41.44 - Epsilon: 0.3936
# Episode 187/500 - Total Reward: 21.0 - Average Reward: 41.25 - Epsilon: 0.3917
# Episode 188/500 - Total Reward: 12.0 - Average Reward: 41.04 - Epsilon: 0.3897
# Episode 189/500 - Total Reward: 138.0 - Average Reward: 41.93 - Epsilon: 0.3878
# Episode 190/500 - Total Reward: 36.0 - Average Reward: 42.16 - Epsilon: 0.3858
# Episode 191/500 - Total Reward: 85.0 - Average Reward: 42.78 - Epsilon: 0.3839
# Episode 192/500 - Total Reward: 46.0 - Average Reward: 42.99 - Epsilon: 0.3820
# Episode 193/500 - Total Reward: 175.0 - Average Reward: 44.30 - Epsilon: 0.3801
# Episode 194/500 - Total Reward: 188.0 - Average Reward: 45.98 - Epsilon: 0.3782
# Episode 195/500 - Total Reward: 144.0 - Average Reward: 47.29 - Epsilon: 0.3763
# Episode 196/500 - Total Reward: 141.0 - Average Reward: 48.52 - Epsilon: 0.3744
# Episode 197/500 - Total Reward: 171.0 - Average Reward: 49.88 - Epsilon: 0.3725
# Episode 198/500 - Total Reward: 41.0 - Average Reward: 50.16 - Epsilon: 0.3707
# Episode 199/500 - Total Reward: 104.0 - Average Reward: 51.05 - Epsilon: 0.3688
# Episode 200/500 - Total Reward: 94.0 - Average Reward: 51.82 - Epsilon: 0.3670
# Episode 201/500 - Total Reward: 128.0 - Average Reward: 52.61 - Epsilon: 0.3651
# Episode 202/500 - Total Reward: 16.0 - Average Reward: 52.49 - Epsilon: 0.3633
# Episode 203/500 - Total Reward: 18.0 - Average Reward: 52.04 - Epsilon: 0.3615
# Episode 204/500 - Total Reward: 56.0 - Average Reward: 52.27 - Epsilon: 0.3597
# Episode 205/500 - Total Reward: 140.0 - Average Reward: 53.24 - Epsilon: 0.3579
# Episode 206/500 - Total Reward: 129.0 - Average Reward: 54.14 - Epsilon: 0.3561
# Episode 207/500 - Total Reward: 53.0 - Average Reward: 54.17 - Epsilon: 0.3543
# Episode 208/500 - Total Reward: 41.0 - Average Reward: 54.46 - Epsilon: 0.3525
# Episode 209/500 - Total Reward: 107.0 - Average Reward: 55.39 - Epsilon: 0.3508
# Episode 210/500 - Total Reward: 95.0 - Average Reward: 56.11 - Epsilon: 0.3490
# Episode 211/500 - Total Reward: 225.0 - Average Reward: 58.17 - Epsilon: 0.3473
# Episode 212/500 - Total Reward: 115.0 - Average Reward: 59.02 - Epsilon: 0.3455
# Episode 213/500 - Total Reward: 36.0 - Average Reward: 59.11 - Epsilon: 0.3438
# Episode 214/500 - Total Reward: 242.0 - Average Reward: 61.03 - Epsilon: 0.3421
# Episode 215/500 - Total Reward: 231.0 - Average Reward: 62.64 - Epsilon: 0.3404
# Episode 216/500 - Total Reward: 109.0 - Average Reward: 63.62 - Epsilon: 0.3387
# Episode 217/500 - Total Reward: 83.0 - Average Reward: 63.75 - Epsilon: 0.3370
# Episode 218/500 - Total Reward: 138.0 - Average Reward: 64.79 - Epsilon: 0.3353
# Episode 219/500 - Total Reward: 19.0 - Average Reward: 64.54 - Epsilon: 0.3336
# Episode 220/500 - Total Reward: 12.0 - Average Reward: 64.54 - Epsilon: 0.3320
# Episode 221/500 - Total Reward: 49.0 - Average Reward: 64.73 - Epsilon: 0.3303
# Episode 222/500 - Total Reward: 113.0 - Average Reward: 65.44 - Epsilon: 0.3286
# Episode 223/500 - Total Reward: 47.0 - Average Reward: 65.71 - Epsilon: 0.3270
# Episode 224/500 - Total Reward: 151.0 - Average Reward: 67.11 - Epsilon: 0.3254
# Episode 225/500 - Total Reward: 67.0 - Average Reward: 66.81 - Epsilon: 0.3237
# Episode 226/500 - Total Reward: 120.0 - Average Reward: 67.87 - Epsilon: 0.3221
# Episode 227/500 - Total Reward: 115.0 - Average Reward: 68.53 - Epsilon: 0.3205
# Episode 228/500 - Total Reward: 23.0 - Average Reward: 68.62 - Epsilon: 0.3189
# Episode 229/500 - Total Reward: 112.0 - Average Reward: 69.32 - Epsilon: 0.3173
# Episode 230/500 - Total Reward: 108.0 - Average Reward: 70.27 - Epsilon: 0.3157
# Episode 231/500 - Total Reward: 120.0 - Average Reward: 71.29 - Epsilon: 0.3141
# Episode 232/500 - Total Reward: 108.0 - Average Reward: 72.16 - Epsilon: 0.3126
# Episode 233/500 - Total Reward: 112.0 - Average Reward: 73.11 - Epsilon: 0.3110
# Episode 234/500 - Total Reward: 134.0 - Average Reward: 73.87 - Epsilon: 0.3095
# Episode 235/500 - Total Reward: 11.0 - Average Reward: 73.51 - Epsilon: 0.3079
# Episode 236/500 - Total Reward: 73.0 - Average Reward: 74.03 - Epsilon: 0.3064
# Episode 237/500 - Total Reward: 89.0 - Average Reward: 74.81 - Epsilon: 0.3048
# Episode 238/500 - Total Reward: 72.0 - Average Reward: 75.02 - Epsilon: 0.3033
# Episode 239/500 - Total Reward: 116.0 - Average Reward: 76.07 - Epsilon: 0.3018
# Episode 240/500 - Total Reward: 217.0 - Average Reward: 78.01 - Epsilon: 0.3003
# Episode 241/500 - Total Reward: 133.0 - Average Reward: 79.22 - Epsilon: 0.2988
# Episode 242/500 - Total Reward: 22.0 - Average Reward: 78.74 - Epsilon: 0.2973
# Episode 243/500 - Total Reward: 209.0 - Average Reward: 80.67 - Epsilon: 0.2958
# Episode 244/500 - Total Reward: 103.0 - Average Reward: 81.44 - Epsilon: 0.2943
# Episode 245/500 - Total Reward: 74.0 - Average Reward: 81.70 - Epsilon: 0.2929
# Episode 246/500 - Total Reward: 111.0 - Average Reward: 82.64 - Epsilon: 0.2914
# Episode 247/500 - Total Reward: 21.0 - Average Reward: 82.44 - Epsilon: 0.2899
# Episode 248/500 - Total Reward: 109.0 - Average Reward: 83.01 - Epsilon: 0.2885
# Episode 249/500 - Total Reward: 105.0 - Average Reward: 83.60 - Epsilon: 0.2870
# Episode 250/500 - Total Reward: 13.0 - Average Reward: 83.43 - Epsilon: 0.2856
# Episode 251/500 - Total Reward: 53.0 - Average Reward: 83.46 - Epsilon: 0.2842
# Episode 252/500 - Total Reward: 17.0 - Average Reward: 83.42 - Epsilon: 0.2828
# Episode 253/500 - Total Reward: 111.0 - Average Reward: 84.07 - Epsilon: 0.2813
# Episode 254/500 - Total Reward: 109.0 - Average Reward: 84.73 - Epsilon: 0.2799
# Episode 255/500 - Total Reward: 131.0 - Average Reward: 85.68 - Epsilon: 0.2785
# Episode 256/500 - Total Reward: 52.0 - Average Reward: 85.88 - Epsilon: 0.2771
# Episode 257/500 - Total Reward: 15.0 - Average Reward: 85.33 - Epsilon: 0.2758
# Episode 258/500 - Total Reward: 107.0 - Average Reward: 86.27 - Epsilon: 0.2744
# Episode 259/500 - Total Reward: 104.0 - Average Reward: 87.18 - Epsilon: 0.2730
# Episode 260/500 - Total Reward: 36.0 - Average Reward: 86.47 - Epsilon: 0.2716
# Episode 261/500 - Total Reward: 17.0 - Average Reward: 85.80 - Epsilon: 0.2703
# Episode 262/500 - Total Reward: 25.0 - Average Reward: 84.45 - Epsilon: 0.2689
# Episode 263/500 - Total Reward: 14.0 - Average Reward: 83.33 - Epsilon: 0.2676
# Episode 264/500 - Total Reward: 176.0 - Average Reward: 84.66 - Epsilon: 0.2663
# Episode 265/500 - Total Reward: 71.0 - Average Reward: 85.21 - Epsilon: 0.2649
# Episode 266/500 - Total Reward: 382.0 - Average Reward: 88.53 - Epsilon: 0.2636
# Episode 267/500 - Total Reward: 20.0 - Average Reward: 88.22 - Epsilon: 0.2623
# Episode 268/500 - Total Reward: 12.0 - Average Reward: 87.83 - Epsilon: 0.2610
# Episode 269/500 - Total Reward: 114.0 - Average Reward: 88.83 - Epsilon: 0.2597
# Episode 270/500 - Total Reward: 113.0 - Average Reward: 88.88 - Epsilon: 0.2584
# Episode 271/500 - Total Reward: 31.0 - Average Reward: 88.82 - Epsilon: 0.2571
# Episode 272/500 - Total Reward: 43.0 - Average Reward: 88.08 - Epsilon: 0.2558
# Episode 273/500 - Total Reward: 15.0 - Average Reward: 87.71 - Epsilon: 0.2545
# Episode 274/500 - Total Reward: 18.0 - Average Reward: 87.34 - Epsilon: 0.2532
# Episode 275/500 - Total Reward: 104.0 - Average Reward: 88.07 - Epsilon: 0.2520
# Episode 276/500 - Total Reward: 108.0 - Average Reward: 88.45 - Epsilon: 0.2507
# Episode 277/500 - Total Reward: 30.0 - Average Reward: 88.44 - Epsilon: 0.2495
# Episode 278/500 - Total Reward: 132.0 - Average Reward: 89.25 - Epsilon: 0.2482
# Episode 279/500 - Total Reward: 182.0 - Average Reward: 89.96 - Epsilon: 0.2470
# Episode 280/500 - Total Reward: 103.0 - Average Reward: 90.63 - Epsilon: 0.2457
# Episode 281/500 - Total Reward: 47.0 - Average Reward: 90.50 - Epsilon: 0.2445
# Episode 282/500 - Total Reward: 115.0 - Average Reward: 91.24 - Epsilon: 0.2433
# Episode 283/500 - Total Reward: 71.0 - Average Reward: 91.54 - Epsilon: 0.2421
# Episode 284/500 - Total Reward: 49.0 - Average Reward: 91.31 - Epsilon: 0.2409
# Episode 285/500 - Total Reward: 152.0 - Average Reward: 92.48 - Epsilon: 0.2397
# Episode 286/500 - Total Reward: 105.0 - Average Reward: 92.30 - Epsilon: 0.2385
# Episode 287/500 - Total Reward: 37.0 - Average Reward: 92.46 - Epsilon: 0.2373
# Episode 288/500 - Total Reward: 264.0 - Average Reward: 94.98 - Epsilon: 0.2361
# Episode 289/500 - Total Reward: 188.0 - Average Reward: 95.48 - Epsilon: 0.2349
# Episode 290/500 - Total Reward: 58.0 - Average Reward: 95.70 - Epsilon: 0.2337
# Episode 291/500 - Total Reward: 67.0 - Average Reward: 95.52 - Epsilon: 0.2326
# Episode 292/500 - Total Reward: 151.0 - Average Reward: 96.57 - Epsilon: 0.2314
# Episode 293/500 - Total Reward: 55.0 - Average Reward: 95.37 - Epsilon: 0.2302
# Episode 294/500 - Total Reward: 114.0 - Average Reward: 94.63 - Epsilon: 0.2291
# Episode 295/500 - Total Reward: 117.0 - Average Reward: 94.36 - Epsilon: 0.2279
# Episode 296/500 - Total Reward: 344.0 - Average Reward: 96.39 - Epsilon: 0.2268
# Episode 297/500 - Total Reward: 138.0 - Average Reward: 96.06 - Epsilon: 0.2257
# Episode 298/500 - Total Reward: 117.0 - Average Reward: 96.82 - Epsilon: 0.2245
# Episode 299/500 - Total Reward: 114.0 - Average Reward: 96.92 - Epsilon: 0.2234
# Episode 300/500 - Total Reward: 116.0 - Average Reward: 97.14 - Epsilon: 0.2223
# Episode 301/500 - Total Reward: 117.0 - Average Reward: 97.03 - Epsilon: 0.2212
# Episode 302/500 - Total Reward: 178.0 - Average Reward: 98.65 - Epsilon: 0.2201
# Episode 303/500 - Total Reward: 130.0 - Average Reward: 99.77 - Epsilon: 0.2190
# Episode 304/500 - Total Reward: 106.0 - Average Reward: 100.27 - Epsilon: 0.2179
# Episode 305/500 - Total Reward: 202.0 - Average Reward: 100.89 - Epsilon: 0.2168
# Episode 306/500 - Total Reward: 201.0 - Average Reward: 101.61 - Epsilon: 0.2157
# Episode 307/500 - Total Reward: 106.0 - Average Reward: 102.14 - Epsilon: 0.2146
# Episode 308/500 - Total Reward: 127.0 - Average Reward: 103.00 - Epsilon: 0.2136
# Episode 309/500 - Total Reward: 233.0 - Average Reward: 104.26 - Epsilon: 0.2125
# Episode 310/500 - Total Reward: 19.0 - Average Reward: 103.50 - Epsilon: 0.2114
# Episode 311/500 - Total Reward: 131.0 - Average Reward: 102.56 - Epsilon: 0.2104
# Episode 312/500 - Total Reward: 249.0 - Average Reward: 103.90 - Epsilon: 0.2093
# Episode 313/500 - Total Reward: 189.0 - Average Reward: 105.43 - Epsilon: 0.2083
# Episode 314/500 - Total Reward: 244.0 - Average Reward: 105.45 - Epsilon: 0.2072
# Episode 315/500 - Total Reward: 50.0 - Average Reward: 103.64 - Epsilon: 0.2062
# Episode 316/500 - Total Reward: 215.0 - Average Reward: 104.70 - Epsilon: 0.2052
# Episode 317/500 - Total Reward: 24.0 - Average Reward: 104.11 - Epsilon: 0.2041
# Episode 318/500 - Total Reward: 11.0 - Average Reward: 102.84 - Epsilon: 0.2031
# Episode 319/500 - Total Reward: 90.0 - Average Reward: 103.55 - Epsilon: 0.2021
# Episode 320/500 - Total Reward: 61.0 - Average Reward: 104.04 - Epsilon: 0.2011
# Episode 321/500 - Total Reward: 35.0 - Average Reward: 103.90 - Epsilon: 0.2001
# Episode 322/500 - Total Reward: 20.0 - Average Reward: 102.97 - Epsilon: 0.1991
# Episode 323/500 - Total Reward: 169.0 - Average Reward: 104.19 - Epsilon: 0.1981
# Episode 324/500 - Total Reward: 192.0 - Average Reward: 104.60 - Epsilon: 0.1971
# Episode 325/500 - Total Reward: 151.0 - Average Reward: 105.44 - Epsilon: 0.1961
# Episode 326/500 - Total Reward: 247.0 - Average Reward: 106.71 - Epsilon: 0.1951
# Episode 327/500 - Total Reward: 110.0 - Average Reward: 106.66 - Epsilon: 0.1942
# Episode 328/500 - Total Reward: 102.0 - Average Reward: 107.45 - Epsilon: 0.1932
# Episode 329/500 - Total Reward: 125.0 - Average Reward: 107.58 - Epsilon: 0.1922
# Episode 330/500 - Total Reward: 167.0 - Average Reward: 108.17 - Epsilon: 0.1913
# Episode 331/500 - Total Reward: 132.0 - Average Reward: 108.29 - Epsilon: 0.1903
# Episode 332/500 - Total Reward: 218.0 - Average Reward: 109.39 - Epsilon: 0.1893
# Episode 333/500 - Total Reward: 253.0 - Average Reward: 110.80 - Epsilon: 0.1884
# Episode 334/500 - Total Reward: 131.0 - Average Reward: 110.77 - Epsilon: 0.1875
# Episode 335/500 - Total Reward: 164.0 - Average Reward: 112.30 - Epsilon: 0.1865
# Episode 336/500 - Total Reward: 151.0 - Average Reward: 113.08 - Epsilon: 0.1856
# Episode 337/500 - Total Reward: 249.0 - Average Reward: 114.68 - Epsilon: 0.1847
# Episode 338/500 - Total Reward: 171.0 - Average Reward: 115.67 - Epsilon: 0.1837
# Episode 339/500 - Total Reward: 230.0 - Average Reward: 116.81 - Epsilon: 0.1828
# Episode 340/500 - Total Reward: 312.0 - Average Reward: 117.76 - Epsilon: 0.1819
# Episode 341/500 - Total Reward: 142.0 - Average Reward: 117.85 - Epsilon: 0.1810
# Episode 342/500 - Total Reward: 16.0 - Average Reward: 117.79 - Epsilon: 0.1801
# Episode 343/500 - Total Reward: 226.0 - Average Reward: 117.96 - Epsilon: 0.1792
# Episode 344/500 - Total Reward: 21.0 - Average Reward: 117.14 - Epsilon: 0.1783
# Episode 345/500 - Total Reward: 225.0 - Average Reward: 118.65 - Epsilon: 0.1774
# Episode 346/500 - Total Reward: 294.0 - Average Reward: 120.48 - Epsilon: 0.1765
# Episode 347/500 - Total Reward: 86.0 - Average Reward: 121.13 - Epsilon: 0.1756
# Episode 348/500 - Total Reward: 21.0 - Average Reward: 120.25 - Epsilon: 0.1748
# Episode 349/500 - Total Reward: 53.0 - Average Reward: 119.73 - Epsilon: 0.1739
# Episode 350/500 - Total Reward: 116.0 - Average Reward: 120.76 - Epsilon: 0.1730
# Episode 351/500 - Total Reward: 130.0 - Average Reward: 121.53 - Epsilon: 0.1721
# Episode 352/500 - Total Reward: 237.0 - Average Reward: 123.73 - Epsilon: 0.1713
# Episode 353/500 - Total Reward: 183.0 - Average Reward: 124.45 - Epsilon: 0.1704
# Episode 354/500 - Total Reward: 13.0 - Average Reward: 123.49 - Epsilon: 0.1696
# Episode 355/500 - Total Reward: 26.0 - Average Reward: 122.44 - Epsilon: 0.1687
# Episode 356/500 - Total Reward: 352.0 - Average Reward: 125.44 - Epsilon: 0.1679
# Episode 357/500 - Total Reward: 268.0 - Average Reward: 127.97 - Epsilon: 0.1670
# Episode 358/500 - Total Reward: 29.0 - Average Reward: 127.19 - Epsilon: 0.1662
# Episode 359/500 - Total Reward: 120.0 - Average Reward: 127.35 - Epsilon: 0.1654
# Episode 360/500 - Total Reward: 209.0 - Average Reward: 129.08 - Epsilon: 0.1646
# Episode 361/500 - Total Reward: 277.0 - Average Reward: 131.68 - Epsilon: 0.1637
# Episode 362/500 - Total Reward: 146.0 - Average Reward: 132.89 - Epsilon: 0.1629
# Episode 363/500 - Total Reward: 174.0 - Average Reward: 134.49 - Epsilon: 0.1621
# Episode 364/500 - Total Reward: 176.0 - Average Reward: 134.49 - Epsilon: 0.1613
# Episode 365/500 - Total Reward: 160.0 - Average Reward: 135.38 - Epsilon: 0.1605
# Episode 366/500 - Total Reward: 116.0 - Average Reward: 132.72 - Epsilon: 0.1597
# Episode 367/500 - Total Reward: 325.0 - Average Reward: 135.77 - Epsilon: 0.1589
# Episode 368/500 - Total Reward: 141.0 - Average Reward: 137.06 - Epsilon: 0.1581
# Episode 369/500 - Total Reward: 11.0 - Average Reward: 136.03 - Epsilon: 0.1573
# Episode 370/500 - Total Reward: 255.0 - Average Reward: 137.45 - Epsilon: 0.1565
# Episode 371/500 - Total Reward: 183.0 - Average Reward: 138.97 - Epsilon: 0.1557
# Episode 372/500 - Total Reward: 325.0 - Average Reward: 141.79 - Epsilon: 0.1549
# Episode 373/500 - Total Reward: 172.0 - Average Reward: 143.36 - Epsilon: 0.1542
# Episode 374/500 - Total Reward: 48.0 - Average Reward: 143.66 - Epsilon: 0.1534
# Episode 375/500 - Total Reward: 46.0 - Average Reward: 143.08 - Epsilon: 0.1526
# Episode 376/500 - Total Reward: 135.0 - Average Reward: 143.35 - Epsilon: 0.1519
# Episode 377/500 - Total Reward: 164.0 - Average Reward: 144.69 - Epsilon: 0.1511
# Episode 378/500 - Total Reward: 153.0 - Average Reward: 144.90 - Epsilon: 0.1504
# Episode 379/500 - Total Reward: 248.0 - Average Reward: 145.56 - Epsilon: 0.1496
# Episode 380/500 - Total Reward: 254.0 - Average Reward: 147.07 - Epsilon: 0.1489
# Episode 381/500 - Total Reward: 281.0 - Average Reward: 149.41 - Epsilon: 0.1481
# Episode 382/500 - Total Reward: 54.0 - Average Reward: 148.80 - Epsilon: 0.1474
# Episode 383/500 - Total Reward: 247.0 - Average Reward: 150.56 - Epsilon: 0.1466
# Episode 384/500 - Total Reward: 10.0 - Average Reward: 150.17 - Epsilon: 0.1459
# Episode 385/500 - Total Reward: 175.0 - Average Reward: 150.40 - Epsilon: 0.1452
# Episode 386/500 - Total Reward: 153.0 - Average Reward: 150.88 - Epsilon: 0.1444
# Episode 387/500 - Total Reward: 62.0 - Average Reward: 151.13 - Epsilon: 0.1437
# Episode 388/500 - Total Reward: 164.0 - Average Reward: 150.13 - Epsilon: 0.1430
# Episode 389/500 - Total Reward: 42.0 - Average Reward: 148.67 - Epsilon: 0.1423
# Episode 390/500 - Total Reward: 154.0 - Average Reward: 149.63 - Epsilon: 0.1416
# Episode 391/500 - Total Reward: 272.0 - Average Reward: 151.68 - Epsilon: 0.1409
# Episode 392/500 - Total Reward: 138.0 - Average Reward: 151.55 - Epsilon: 0.1402
# Episode 393/500 - Total Reward: 70.0 - Average Reward: 151.70 - Epsilon: 0.1395
# Episode 394/500 - Total Reward: 10.0 - Average Reward: 150.66 - Epsilon: 0.1388
# Episode 395/500 - Total Reward: 31.0 - Average Reward: 149.80 - Epsilon: 0.1381
# Episode 396/500 - Total Reward: 56.0 - Average Reward: 146.92 - Epsilon: 0.1374
# Episode 397/500 - Total Reward: 17.0 - Average Reward: 145.71 - Epsilon: 0.1367
# Episode 398/500 - Total Reward: 323.0 - Average Reward: 147.77 - Epsilon: 0.1360
# Episode 399/500 - Total Reward: 228.0 - Average Reward: 148.91 - Epsilon: 0.1353
# Episode 400/500 - Total Reward: 310.0 - Average Reward: 150.85 - Epsilon: 0.1347
# Episode 401/500 - Total Reward: 309.0 - Average Reward: 152.77 - Epsilon: 0.1340
# Episode 402/500 - Total Reward: 37.0 - Average Reward: 151.36 - Epsilon: 0.1333
# Episode 403/500 - Total Reward: 500.0 - Average Reward: 155.06 - Epsilon: 0.1326
# Episode 404/500 - Total Reward: 105.0 - Average Reward: 155.05 - Epsilon: 0.1320
# Episode 405/500 - Total Reward: 11.0 - Average Reward: 153.14 - Epsilon: 0.1313
# Episode 406/500 - Total Reward: 381.0 - Average Reward: 154.94 - Epsilon: 0.1307
# Episode 407/500 - Total Reward: 37.0 - Average Reward: 154.25 - Epsilon: 0.1300
# Episode 408/500 - Total Reward: 258.0 - Average Reward: 155.56 - Epsilon: 0.1294
# Episode 409/500 - Total Reward: 285.0 - Average Reward: 156.08 - Epsilon: 0.1287
# Episode 410/500 - Total Reward: 234.0 - Average Reward: 158.23 - Epsilon: 0.1281
# Episode 411/500 - Total Reward: 15.0 - Average Reward: 157.07 - Epsilon: 0.1274
# Episode 412/500 - Total Reward: 139.0 - Average Reward: 155.97 - Epsilon: 0.1268
# Episode 413/500 - Total Reward: 44.0 - Average Reward: 154.52 - Epsilon: 0.1262
# Episode 414/500 - Total Reward: 400.0 - Average Reward: 156.08 - Epsilon: 0.1255
# Episode 415/500 - Total Reward: 13.0 - Average Reward: 155.71 - Epsilon: 0.1249
# Episode 416/500 - Total Reward: 253.0 - Average Reward: 156.09 - Epsilon: 0.1243
# Episode 417/500 - Total Reward: 58.0 - Average Reward: 156.43 - Epsilon: 0.1237
# Episode 418/500 - Total Reward: 58.0 - Average Reward: 156.90 - Epsilon: 0.1230
# Episode 419/500 - Total Reward: 477.0 - Average Reward: 160.77 - Epsilon: 0.1224
# Episode 420/500 - Total Reward: 217.0 - Average Reward: 162.33 - Epsilon: 0.1218
# Episode 421/500 - Total Reward: 36.0 - Average Reward: 162.34 - Epsilon: 0.1212
# Episode 422/500 - Total Reward: 393.0 - Average Reward: 166.07 - Epsilon: 0.1206
# Episode 423/500 - Total Reward: 101.0 - Average Reward: 165.39 - Epsilon: 0.1200
# Episode 424/500 - Total Reward: 150.0 - Average Reward: 164.97 - Epsilon: 0.1194
# Episode 425/500 - Total Reward: 179.0 - Average Reward: 165.25 - Epsilon: 0.1188
# Episode 426/500 - Total Reward: 225.0 - Average Reward: 165.03 - Epsilon: 0.1182
# Episode 427/500 - Total Reward: 159.0 - Average Reward: 165.52 - Epsilon: 0.1176
# Episode 428/500 - Total Reward: 205.0 - Average Reward: 166.55 - Epsilon: 0.1170
# Episode 429/500 - Total Reward: 220.0 - Average Reward: 167.50 - Epsilon: 0.1164
# Episode 430/500 - Total Reward: 440.0 - Average Reward: 170.23 - Epsilon: 0.1159
# Episode 431/500 - Total Reward: 277.0 - Average Reward: 171.68 - Epsilon: 0.1153
# Episode 432/500 - Total Reward: 217.0 - Average Reward: 171.67 - Epsilon: 0.1147
# Episode 433/500 - Total Reward: 64.0 - Average Reward: 169.78 - Epsilon: 0.1141
# Episode 434/500 - Total Reward: 433.0 - Average Reward: 172.80 - Epsilon: 0.1136
# Episode 435/500 - Total Reward: 368.0 - Average Reward: 174.84 - Epsilon: 0.1130
# Episode 436/500 - Total Reward: 165.0 - Average Reward: 174.98 - Epsilon: 0.1124
# Episode 437/500 - Total Reward: 275.0 - Average Reward: 175.24 - Epsilon: 0.1119
# Episode 438/500 - Total Reward: 362.0 - Average Reward: 177.15 - Epsilon: 0.1113
# Episode 439/500 - Total Reward: 465.0 - Average Reward: 179.50 - Epsilon: 0.1107
# Episode 440/500 - Total Reward: 178.0 - Average Reward: 178.16 - Epsilon: 0.1102
# Episode 441/500 - Total Reward: 18.0 - Average Reward: 176.92 - Epsilon: 0.1096
# Episode 442/500 - Total Reward: 27.0 - Average Reward: 177.03 - Epsilon: 0.1091
# Episode 443/500 - Total Reward: 322.0 - Average Reward: 177.99 - Epsilon: 0.1085
# Episode 444/500 - Total Reward: 372.0 - Average Reward: 181.50 - Epsilon: 0.1080
# Episode 445/500 - Total Reward: 57.0 - Average Reward: 179.82 - Epsilon: 0.1075
# Episode 446/500 - Total Reward: 500.0 - Average Reward: 181.88 - Epsilon: 0.1069
# Episode 447/500 - Total Reward: 500.0 - Average Reward: 186.02 - Epsilon: 0.1064
# Episode 448/500 - Total Reward: 388.0 - Average Reward: 189.69 - Epsilon: 0.1059
# Episode 449/500 - Total Reward: 232.0 - Average Reward: 191.48 - Epsilon: 0.1053
# Episode 450/500 - Total Reward: 500.0 - Average Reward: 195.32 - Epsilon: 0.1048
# Environment solved in 450 episodes!
# Video will be saved to: /Users/matthew/Documents/ml_projects/videos/
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/gym/wrappers/record_video.py:75: UserWarning: WARN: Overwriting existing videos at /Users/matthew/Documents/ml_projects/videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Moviepy - Building video /Users/matthew/Documents/ml_projects/videos/rl-video-episode-0.mp4.
# Moviepy - Writing video /Users/matthew/Documents/ml_projects/videos/rl-video-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /Users/matthew/Documents/ml_projects/videos/rl-video-episode-0.mp4
# Episode finished with total reward: 500.0
# Latest video file: /Users/matthew/Documents/ml_projects/videos/rl-video-episode-0.mp4
# <video width="600" controls>
#                         <source src="data:video/mp4;base64,..." type="video/mp4" />
#                         Your browser does not support the video tag.
#                        </video>

# %%
video_folder = "/Users/matthew/Documents/ml_projects/videos/"
video_files = glob.glob(os.path.join(video_folder, "*.mp4"))
print(f"Video files in {video_folder}:")
for video in video_files:
    print(video)
# Out:
# Video files in /Users/matthew/Documents/ml_projects/videos/:
# /Users/matthew/Documents/ml_projects/videos/rl-video-episode-0.mp4
